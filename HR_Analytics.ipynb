# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **1. Import your data**

# %%
data=pd.read_csv('HR data-Renege.csv')
data.head(3)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
# 2   28        married  Associate Certification  Female            32
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       05-12-2015
# 1            <15 kms         Consultants             8       03-09-2015
# 2            <15 kms  Internal Referrals             8       17-12-2015
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   29-02-2016                  24                    3       Lateral
# 1   18-12-2015                  20                    8       Lateral
# 2   24-03-2016                  23                    4       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped
# ...

# %% [markdown]
# **2. Find the dimension of the data**

# %%
data.shape
# Out:
# (1999, 17)

# %% [markdown]
# **3. Find the 1st 3 rows of the data**

# %%
data.head(3)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
# 2   28        married  Associate Certification  Female            32
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       05-12-2015
# 1            <15 kms         Consultants             8       03-09-2015
# 2            <15 kms  Internal Referrals             8       17-12-2015
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   29-02-2016                  24                    3       Lateral
# 1   18-12-2015                  20                    8       Lateral
# 2   24-03-2016                  23                    4       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped
# ...

# %% [markdown]
# **4. Find the last 4 rows of the data**

# %%
data.tail(4)
# Out:
#       age marital_status          education_level  gender  percent_hike  \
# 1995   41        married  Associate Certification    Male            13
# 1996   27        married         Associate Degree    Male            12
# 1997   26       divorced         Associate Degree  Female            30
# 1998   43       divorced          Bachelor Degree  Female            39
#
#      distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 1995           > 20 kms        Social Media             3       13-03-2016
# 1996            <15 kms         Consultants             3       05-11-2015
# 1997           > 20 kms  Internal Referrals             8       24-06-2015
# 1998          15-20 kms     Company Website             5       10-03-2015
#
#      date_offered  satisfaction_index  no_companies_worked career_growth  \
# 1995   20-06-2016                  18                    7      Vertical
# 1996   16-01-2016                  25                    5       Lateral
# ...

# %% [markdown]
# **5. Find the information of your data, then tell how many charectors or objects(categorical variables) in your data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1999 non-null   int64
#  1   marital_status        1999 non-null   object
#  2   education_level       1999 non-null   object
#  3   gender                1999 non-null   object
#  4   percent_hike          1999 non-null   int64
#  5   distance_from_home    1999 non-null   object
#  6   sourcing_channel      1999 non-null   object
#  7   total_rounds          1999 non-null   int64
#  8   date_1st_contact      1999 non-null   object
#  9   date_offered          1999 non-null   object
#  10  satisfaction_index    1999 non-null   int64
#  11  no_companies_worked   1999 non-null   int64
#  12  career_growth         1999 non-null   object
#  13  flexi_work            1999 non-null   object
#  14  total_experience      1999 non-null   int64
# ...

# %% [markdown]
# **6. create the table of offer_dropped**

# %% [markdown]
# **to get the count of the people who left the offer**

# %%
data['offer_dropped'].value_counts()
# Out:
# Yes    1024
# No      975
# Name: offer_dropped, dtype: int64

# %% [markdown]
# **7. Find the Percentage of peoples who left the job**

# %%
1024/1999*100
# Out:
# 51.2256128064032

# %% [markdown]
# **51% people left the job**

# %% [markdown]
# **8. Check is there any missing values in the data**

# %%
data.isna().sum()
# Out:
# age                     0
# marital_status          0
# education_level         0
# gender                  0
# percent_hike            0
# distance_from_home      0
# sourcing_channel        0
# total_rounds            0
# date_1st_contact        0
# date_offered            0
# satisfaction_index      0
# no_companies_worked     0
# career_growth           0
# flexi_work              0
# total_experience        0
# timely_communication    0
# offer_dropped           0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                     0
# marital_status          0
# education_level         0
# gender                  0
# percent_hike            0
# distance_from_home      0
# sourcing_channel        0
# total_rounds            0
# date_1st_contact        0
# date_offered            0
# satisfaction_index      0
# no_companies_worked     0
# career_growth           0
# flexi_work              0
# total_experience        0
# timely_communication    0
# offer_dropped           0
# dtype: int64

# %% [markdown]
# **there is no missing values**

# %% [markdown]
# **9.Find the Univariate summary of the data**

# %%
data.groupby('offer_dropped').mean()
# Out:
#                      age  percent_hike  total_rounds  satisfaction_index  \
# offer_dropped
# No             35.780513     23.539487      5.830769           59.190769
# Yes            34.995117     18.779297      7.106445           22.476562
#
#                no_companies_worked  total_experience
# offer_dropped
# No                        4.792821         11.854359
# Yes                       4.768555         10.388672

# %% [markdown]
# **find the average of each category in job offered and try to plot it in a graph**

# %%
data.head(2)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       05-12-2015
# 1            <15 kms         Consultants             8       03-09-2015
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   29-02-2016                  24                    3       Lateral
# 1   18-12-2015                  20                    8       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped
# 0        Yes                 5                   No           Yes
# 1        Yes                13                   No           Yes

# %%
mean=data[['age','percent_hike','total_rounds','satisfaction_index','no_companies_worked']].mean()
mean
# Out:
# age                    35.378189
# percent_hike           21.101051
# total_rounds            6.484242
# satisfaction_index     40.383692
# no_companies_worked     4.780390
# dtype: float64

# %%
data[['age','percent_hike','total_rounds','satisfaction_index','no_companies_worked']].median()
# Out:
# age                    35.0
# percent_hike           19.0
# total_rounds            7.0
# satisfaction_index     29.0
# no_companies_worked     5.0
# dtype: float64

# %%
data[['age','percent_hike','total_rounds','satisfaction_index','no_companies_worked']].mode()
# Out:
#    age  percent_hike  total_rounds  satisfaction_index  no_companies_worked
# 0   41            13             3                  30                    5

# %%
data[['age','percent_hike','total_rounds','satisfaction_index','no_companies_worked']].min()
# Out:
# age                    25
# percent_hike           10
# total_rounds            3
# satisfaction_index     15
# no_companies_worked     1
# dtype: int64

# %%
data[['age','percent_hike','total_rounds','satisfaction_index','no_companies_worked']].max()
# Out:
# age                    46
# percent_hike           40
# total_rounds           10
# satisfaction_index     95
# no_companies_worked     8
# dtype: int64

# %% [markdown]
# Range

# %%
#Range
age=46-25
percentage=40-10
total_rounds=10-3
satis_ind=95-15
lack_companywork=8-1

print(age)
print(percentage)
print(total_rounds)
print(satis_ind)
print(lack_companywork)
# Out:
# 21
# 30
# 7
# 80
# 7

# %%
#Variance
data.var()
# Out:
# C:\Users\kchri\AppData\Local\Temp\ipykernel_19540\2374918984.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# age                     37.608653
# percent_hike            79.755549
# total_rounds             6.787414
# satisfaction_index     551.559914
# no_companies_worked      3.707003
# total_experience        36.691474
# dtype: float64

# %%
#standard deviation
data.std()
# Out:
# C:\Users\kchri\AppData\Local\Temp\ipykernel_19540\2150623514.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# age                     6.132589
# percent_hike            8.930596
# total_rounds            2.605267
# satisfaction_index     23.485313
# no_companies_worked     1.925358
# total_experience        6.057349
# dtype: float64

# %%
data.head(2)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       05-12-2015
# 1            <15 kms         Consultants             8       03-09-2015
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   29-02-2016                  24                    3       Lateral
# 1   18-12-2015                  20                    8       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped
# 0        Yes                 5                   No           Yes
# 1        Yes                13                   No           Yes

# %%
#Q1
data.quantile(0.25)
# Out:
# age                    30.0
# percent_hike           13.0
# total_rounds            4.0
# satisfaction_index     22.0
# no_companies_worked     3.0
# total_experience        6.0
# Name: 0.25, dtype: float64

# %%
#Q2
data.quantile(0.50)
# Out:
# age                    35.0
# percent_hike           19.0
# total_rounds            7.0
# satisfaction_index     29.0
# no_companies_worked     5.0
# total_experience       11.0
# Name: 0.5, dtype: float64

# %%
#Q3
data.quantile(0.75)
# Out:
# age                    41.0
# percent_hike           29.0
# total_rounds            9.0
# satisfaction_index     59.0
# no_companies_worked     6.0
# total_experience       16.0
# Name: 0.75, dtype: float64

# %% [markdown]
# **IQR & QD**

# %% [markdown]
# Age

# %%
#age IQR
IQRage=41-30
IQRage
# Out:
# 11

# %%
QDage=(IQRage/2)
QDage
# Out:
# 5.5

# %% [markdown]
# Percentage_hike

# %%
#Percentage_hike IQR
IQRhike=29-13
IQRhike
# Out:
# 16

# %%
QDhike=IQRhike/2
QDhike
# Out:
# 8.0

# %% [markdown]
# Total_rounds

# %%
#Total rounds
IQRound=9-4
IQRound
# Out:
# 5

# %%
QDround=IQRound/2
QDround
# Out:
# 2.5

# %% [markdown]
# satisfaction index

# %%
#satisfaction_index
IQRindex=59-22
IQRindex
# Out:
# 37

# %%
QDindex=IQRindex/2
QDindex
# Out:
# 18.5

# %% [markdown]
# No companies worked

# %%
#no_companies_worked  
IQRcw=6-3
IQRcw
# Out:
# 3

# %%
QDcw=IQRcw/2
QDcw
# Out:
# 1.5

# %% [markdown]
# Total experience

# %%
#total_experience 
IQRexp=16-6
IQRexp
# Out:
# 10

# %%
QDexp=IQRexp/2
QDexp
# Out:
# 5.0

# %%
data.head(3)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
# 2   28        married  Associate Certification  Female            32
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       05-12-2015
# 1            <15 kms         Consultants             8       03-09-2015
# 2            <15 kms  Internal Referrals             8       17-12-2015
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   29-02-2016                  24                    3       Lateral
# 1   18-12-2015                  20                    8       Lateral
# 2   24-03-2016                  23                    4       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped
# ...

# %%
mean
# Out:
# age                    35.378189
# percent_hike           21.101051
# total_rounds            6.484242
# satisfaction_index     40.383692
# no_companies_worked     4.780390
# dtype: float64

# %%
data.describe()
# Out:
#                age  percent_hike  total_rounds  satisfaction_index  \
# count  1999.000000   1999.000000   1999.000000         1999.000000
# mean     35.378189     21.101051      6.484242           40.383692
# std       6.132589      8.930596      2.605267           23.485313
# min      25.000000     10.000000      3.000000           15.000000
# 25%      30.000000     13.000000      4.000000           22.000000
# 50%      35.000000     19.000000      7.000000           29.000000
# 75%      41.000000     29.000000      9.000000           59.000000
# max      46.000000     40.000000     10.000000           95.000000
#
#        no_companies_worked  total_experience
# count          1999.000000       1999.000000
# mean              4.780390         11.103552
# std               1.925358          6.057349
# min               1.000000          1.000000
# 25%               3.000000          6.000000
# 50%               5.000000         11.000000
# ...

# %% [markdown]
# **10. Feature Engineering - create a new variable named JHI(Job_Hopping_index) and calculate JHI  JHI = total_experience/ no_companies_worked**

# %% [markdown]
# #A job hopper is a person who switches jobs frequently for financial or career advancement opportunities.
# In some industries, recruiters and hiring managers may perceive job hoppers in a negative
#  light and think they are unstable or disloyal employees.
#
# **Organisations are anxious to minimise risks in hiring decisions, and, therefore, look closely for potential red flags such as seemingly inexplicable career gaps.**

# %%
#JHI Job_Hopping_index

data['JHI']=data['total_experience']/data['no_companies_worked']
data['JHI']
# Out:
# 0       1.666667
# 1       1.625000
# 2       1.000000
# 3       3.333333
# 4       1.000000
#           ...
# 1994    3.166667
# 1995    2.428571
# 1996    0.600000
# 1997    1.000000
# 1998    2.375000
# Name: JHI, Length: 1999, dtype: float64

# %% [markdown]
# **11. create a new feature days_offer and inside that calculate the days offered = date_offered - date_1st_contact**

# %%
data.columns
# Out:
# Index(['age', 'marital_status', 'education_level', 'gender', 'percent_hike',
#        'distance_from_home', 'sourcing_channel', 'total_rounds',
#        'date_1st_contact', 'date_offered', 'satisfaction_index',
#        'no_companies_worked', 'career_growth', 'flexi_work',
#        'total_experience', 'timely_communication', 'offer_dropped', 'JHI'],
#       dtype='object')

# %%
data[['date_offered', 'date_1st_contact']]=data[['date_offered', 'date_1st_contact']].apply(pd.to_datetime)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1999 non-null   int64
#  1   marital_status        1999 non-null   object
#  2   education_level       1999 non-null   object
#  3   gender                1999 non-null   object
#  4   percent_hike          1999 non-null   int64
#  5   distance_from_home    1999 non-null   object
#  6   sourcing_channel      1999 non-null   object
#  7   total_rounds          1999 non-null   int64
#  8   date_1st_contact      1999 non-null   datetime64[ns]
#  9   date_offered          1999 non-null   datetime64[ns]
#  10  satisfaction_index    1999 non-null   int64
#  11  no_companies_worked   1999 non-null   int64
#  12  career_growth         1999 non-null   object
#  13  flexi_work            1999 non-null   object
# ...

# %%
data['days_offered']= data.date_offered.dt.date - data.date_1st_contact.dt.date
data['days_offered']
# Out:
# 0       293 days
# 1       284 days
# 2        98 days
# 3        71 days
# 4       174 days
#           ...
# 1994     85 days
# 1995     99 days
# 1996    250 days
# 1997     57 days
# 1998   -127 days
# Name: days_offered, Length: 1999, dtype: timedelta64[ns]

# %%
data['Days_offered']= data['days_offered'].dt.days
data['Days_offered']
# Out:
# 0       293
# 1       284
# 2        98
# 3        71
# 4       174
#        ...
# 1994     85
# 1995     99
# 1996    250
# 1997     57
# 1998   -127
# Name: Days_offered, Length: 1999, dtype: int64

# %%
data.drop(['days_offered'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1999 non-null   int64
#  1   marital_status        1999 non-null   object
#  2   education_level       1999 non-null   object
#  3   gender                1999 non-null   object
#  4   percent_hike          1999 non-null   int64
#  5   distance_from_home    1999 non-null   object
#  6   sourcing_channel      1999 non-null   object
#  7   total_rounds          1999 non-null   int64
#  8   date_1st_contact      1999 non-null   datetime64[ns]
#  9   date_offered          1999 non-null   datetime64[ns]
#  10  satisfaction_index    1999 non-null   int64
#  11  no_companies_worked   1999 non-null   int64
#  12  career_growth         1999 non-null   object
#  13  flexi_work            1999 non-null   object
# ...

# %%
data.head(3)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
# 2   28        married  Associate Certification  Female            32
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       2015-05-12
# 1            <15 kms         Consultants             8       2015-03-09
# 2            <15 kms  Internal Referrals             8       2015-12-17
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   2016-02-29                  24                    3       Lateral
# 1   2015-12-18                  20                    8       Lateral
# 2   2016-03-24                  23                    4       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped       JHI  \
# ...

# %%
data.tail(3)
# Out:
#       age marital_status   education_level  gender  percent_hike  \
# 1996   27        married  Associate Degree    Male            12
# 1997   26       divorced  Associate Degree  Female            30
# 1998   43       divorced   Bachelor Degree  Female            39
#
#      distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 1996            <15 kms         Consultants             3       2015-05-11
# 1997           > 20 kms  Internal Referrals             8       2015-06-24
# 1998          15-20 kms     Company Website             5       2015-10-03
#
#      date_offered  satisfaction_index  no_companies_worked career_growth  \
# 1996   2016-01-16                  25                    5       Lateral
# 1997   2015-08-20                  62                    2      Vertical
# 1998   2015-05-29                  82                    8       Lateral
#
#      flexi_work  total_experience timely_communication offer_dropped    JHI  \
# ...

# %%
#to find the count of gender, to find how many offers are send on each gender

gen=data['gender'].value_counts()
gen
# Out:
# Male      1517
# Female     482
# Name: gender, dtype: int64

# %%
gen.plot(kind='pie',cmap='cool',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
gen.plot(kind='bar',color='c')
plt.title('Gender',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
edu=data['education_level'].value_counts()
edu
# Out:
# Associate Degree           624
# Associate Certification    590
# Bachelor Degree            469
# Master Degree              316
# Name: education_level, dtype: int64

# %%
edu.plot(kind='pie',cmap='cool',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='education_level'>

# %%
edu.plot(kind='bar',color='c')
plt.title('Education Level',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Education Level')

# %% [markdown]
# **12. Create a table of Marital Status**

# %%
mar=data['marital_status'].value_counts()
mar
# Out:
# married     1389
# single       400
# divorced     205
# unknown        5
# Name: marital_status, dtype: int64

# %%
mar.plot(kind='pie', cmap='cool',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='marital_status'>

# %%
mar.plot(kind='bar',color='c')
plt.title('Marital Level',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Marital Level')

# %%
sourc=data['sourcing_channel'].value_counts()
sourc
# Out:
# Job Portals           486
# Consultants           459
# Social Media          420
# Company Website       353
# Internal Referrals    281
# Name: sourcing_channel, dtype: int64

# %%
sourc.plot(kind='pie',cmap='cool',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='sourcing_channel'>

# %%
sourc.plot(kind='bar',color='c')
plt.title('Sourcing Channel',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Sourcing Channel')

# %%
data.head(2)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       2015-05-12
# 1            <15 kms         Consultants             8       2015-03-09
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   2016-02-29                  24                    3       Lateral
# 1   2015-12-18                  20                    8       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped       JHI  \
# 0        Yes                 5                   No           Yes  1.666667
# 1        Yes                13                   No           Yes  1.625000
#
#    Days_offered
# 0           293
# 1           284

# %%
carr=data['career_growth'].value_counts()
carr
# Out:
# Lateral     1286
# Vertical     713
# Name: career_growth, dtype: int64

# %%
carr.plot(kind='pie',cmap='cool',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='career_growth'>

# %%
carr.plot(kind='bar',color='c')
plt.title('Career Growth',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Career Growth')

# %%
flx=data['flexi_work'].value_counts()
flx
# Out:
# Yes    1177
# No      822
# Name: flexi_work, dtype: int64

# %%
flx.plot(cmap='cool',autopct='%1.2f%%', kind='pie')
# Out:
# <AxesSubplot:ylabel='flexi_work'>

# %%
flx.plot(kind='bar',color='c')
plt.title('Flexi work',fontdict={'fontsize':15,'fontweight':4,'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Flexi work')

# %%
data.head(2)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       2015-05-12
# 1            <15 kms         Consultants             8       2015-03-09
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   2016-02-29                  24                    3       Lateral
# 1   2015-12-18                  20                    8       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped       JHI  \
# 0        Yes                 5                   No           Yes  1.666667
# 1        Yes                13                   No           Yes  1.625000
#
#    Days_offered
# 0           293
# 1           284

# %%
offdr=data['offer_dropped'].value_counts()
offdr
# Out:
# Yes    1024
# No      975
# Name: offer_dropped, dtype: int64

# %%
offdr.plot(autopct='%1.2f%%',kind='pie',cmap='cool')
# Out:
# <AxesSubplot:ylabel='offer_dropped'>

# %%
offdr.plot(kind='bar',color='c')
plt.title('Offer dropped',fontdict={'fontsize':15,'fontweight':4, 'color':'darkcyan'})
# Out:
# Text(0.5, 1.0, 'Offer dropped')

# %% [markdown]
# **Boxplot of univariables**

# %%
sns.boxplot(y='age',data=data)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.boxplot(y='percent_hike',data=data)
# Out:
# <AxesSubplot:ylabel='percent_hike'>

# %%
sns.boxplot(y='total_rounds',data=data)
# Out:
# <AxesSubplot:ylabel='total_rounds'>

# %%
sns.boxplot(y='satisfaction_index',data=data)
# Out:
# <AxesSubplot:ylabel='satisfaction_index'>

# %%
sns.boxplot(y='no_companies_worked',data=data)
# Out:
# <AxesSubplot:ylabel='no_companies_worked'>

# %%
sns.boxplot(y='JHI',data=data)
# Out:
# <AxesSubplot:ylabel='JHI'>

# %% [markdown]
# **Histograms of univariables**

# %%
data.hist('age', color="lightblue",edgecolor = 'black')
plt.title('age')
# Out:
# Text(0.5, 1.0, 'age')

# %%
data.hist('percent_hike', color="lightblue",edgecolor = 'black')
plt.title('percent_hike')
# Out:
# Text(0.5, 1.0, 'percent_hike')

# %%
data.hist('JHI', color="lightblue",edgecolor = 'black')
plt.title('JHI')
# Out:
# Text(0.5, 1.0, 'JHI')

# %% [markdown]
# **Density Plots**
#
# A density plot is a representation of the distribution of a numeric variable. It uses a kernel density estimate to show the probability density function of the variable (see more). It is a smoothed version of the histogram and is used in the same concept.

# %%
plt.figure(figsize=(5,5))
data['JHI'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(data['JHI'],shade=True)
# Out:
# <AxesSubplot:xlabel='JHI', ylabel='Density'>

# %% [markdown]
# **Distplots**
#
# Seaborn distplot lets you show a histogram with a line on it. This can be shown in all kinds of variations.

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.distplot(data['JHI'],color='black',rug=True)
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='JHI', ylabel='Density'>

# %% [markdown]
# **Violin plots**
#
# A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data.

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(data['JHI'],orient='vertical')
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='JHI'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(data['age'],orient='vertical')
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### **Bivariable analysis**

# %%
data.columns
# Out:
# Index(['age', 'marital_status', 'education_level', 'gender', 'percent_hike',
#        'distance_from_home', 'sourcing_channel', 'total_rounds',
#        'date_1st_contact', 'date_offered', 'satisfaction_index',
#        'no_companies_worked', 'career_growth', 'flexi_work',
#        'total_experience', 'timely_communication', 'offer_dropped', 'JHI',
#        'Days_offered'],
#       dtype='object')

# %%
data.head(2)
# Out:
#    age marital_status          education_level  gender  percent_hike  \
# 0   29        married  Associate Certification  Female            27
# 1   37        married         Associate Degree  Female            22
#
#   distance_from_home    sourcing_channel  total_rounds date_1st_contact  \
# 0            <15 kms  Internal Referrals             8       2015-05-12
# 1            <15 kms         Consultants             8       2015-03-09
#
#   date_offered  satisfaction_index  no_companies_worked career_growth  \
# 0   2016-02-29                  24                    3       Lateral
# 1   2015-12-18                  20                    8       Lateral
#
#   flexi_work  total_experience timely_communication offer_dropped       JHI  \
# 0        Yes                 5                   No           Yes  1.666667
# 1        Yes                13                   No           Yes  1.625000
#
#    Days_offered
# 0           293
# 1           284

# %% [markdown]
# **13. Create a table of Marital Status and offer dropped**

# %%
MO=pd.crosstab(data['marital_status'],data['offer_dropped'])
MO
# Out:
# offer_dropped    No  Yes
# marital_status
# divorced        103  102
# married         678  711
# single          190  210
# unknown           4    1

# %%
MO.plot(kind='bar', cmap ='coolwarm')
plt.title('Marital_status vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Marital_status vs offer dropped')

# %%
EO=pd.crosstab(data['education_level'],data['offer_dropped'])
EO
# Out:
# offer_dropped             No  Yes
# education_level
# Associate Certification  289  301
# Associate Degree         316  308
# Bachelor Degree          221  248
# Master Degree            149  167

# %%
EO.plot(kind='bar', cmap ='coolwarm')
plt.title('Educational vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Educational vs offer dropped')

# %%
GO=pd.crosstab(data['gender'],data['offer_dropped'])
GO
# Out:
# offer_dropped   No  Yes
# gender
# Female         247  235
# Male           728  789

# %%
GO.plot(kind='bar', cmap ='coolwarm')
plt.title('Educational vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Educational vs offer dropped')

# %%
SO=pd.crosstab(data['sourcing_channel'],data['offer_dropped'])
SO
# Out:
# offer_dropped        No  Yes
# sourcing_channel
# Company Website     204  149
# Consultants         194  265
# Internal Referrals   85  196
# Job Portals         284  202
# Social Media        208  212

# %%
SO.plot(kind='bar', cmap ='coolwarm')
plt.title('Sourcing channel vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Sourcing channel vs offer dropped')

# %%
CO=pd.crosstab(data['career_growth'],data['offer_dropped'])
CO
# Out:
# offer_dropped   No  Yes
# career_growth
# Lateral        492  794
# Vertical       483  230

# %%
CO.plot(kind='bar', cmap ='coolwarm')
plt.title('Career growth vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Career growth vs offer dropped')

# %%
FO=pd.crosstab(data['flexi_work'],data['offer_dropped'])
FO
# Out:
# offer_dropped   No  Yes
# flexi_work
# No             482  340
# Yes            493  684

# %%
EO.plot(kind='bar', cmap ='coolwarm')
plt.title('Flexi work vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Flexi work vs offer dropped')

# %%
TO=pd.crosstab(data['timely_communication'],data['offer_dropped'])
TO
# Out:
# offer_dropped          No  Yes
# timely_communication
# No                    481  707
# Yes                   494  317

# %%
TO.plot(kind='bar', cmap ='coolwarm')
plt.title('Timely communication vs offer dropped', fontdict= {'fontsize':20, 'fontweight':5, 'color':'blue'})
# Out:
# Text(0.5, 1.0, 'Timely communication vs offer dropped')

# %% [markdown]
# **14. create a table of offer dropped and age by mean value**

# %%
data.groupby('offer_dropped').mean()[['age']]
# Out:
#                      age
# offer_dropped
# No             35.780513
# Yes            34.995117

# %% [markdown]
# **insight :mean age does not seem to be a reason of offer drop**

# %%
med_age = data.groupby('offer_dropped').median()[['age']]
med_age
# Out:
#                 age
# offer_dropped
# No             36.0
# Yes            35.0

# %% [markdown]
# **15. same like 14th question create for other continues variables with offer dropped**

# %%
data.columns
# Out:
# Index(['age', 'marital_status', 'education_level', 'gender', 'percent_hike',
#        'distance_from_home', 'sourcing_channel', 'total_rounds',
#        'date_1st_contact', 'date_offered', 'satisfaction_index',
#        'no_companies_worked', 'career_growth', 'flexi_work',
#        'total_experience', 'timely_communication', 'offer_dropped', 'JHI',
#        'Days_offered'],
#       dtype='object')

# %%
data.groupby('offer_dropped').mean()[['age', 'percent_hike', 'total_rounds', 'satisfaction_index', 'no_companies_worked', 'total_experience', 'JHI', 'Days_offered']]
# Out:
#                      age  percent_hike  total_rounds  satisfaction_index  \
# offer_dropped
# No             35.780513     23.539487      5.830769           59.190769
# Yes            34.995117     18.779297      7.106445           22.476562
#
#                no_companies_worked  total_experience       JHI  Days_offered
# offer_dropped
# No                        4.792821         11.854359  2.592486     58.425641
# Yes                       4.768555         10.388672  2.154035     84.018555

# %%
data.groupby('offer_dropped').mean()[['percent_hike']]
# Out:
#                percent_hike
# offer_dropped
# No                23.539487
# Yes               18.779297

# %% [markdown]
# **since the hike in salary is high there is agreat chance to have people leave the job**

# %%
data.groupby('offer_dropped').mean()[['satisfaction_index']]
# Out:
#                satisfaction_index
# offer_dropped
# No                      59.190769
# Yes                     22.476562

# %% [markdown]
# **if the average of the job satisfaction is 40 only there is a problem in the hiring way.**

# %%
data.groupby('offer_dropped').mean()[['total_rounds']]
# Out:
#                total_rounds
# offer_dropped
# No                 5.830769
# Yes                7.106445

# %% [markdown]
# **the more rounds people don't like to join the organization high no.of rounds people don't like the organization**

# %%
data.groupby('offer_dropped').mean()[['JHI']]
# Out:
#                     JHI
# offer_dropped
# No             2.592486
# Yes            2.154035

# %%
#Doubt in this code

data.groupby('offer_dropped').mean()[['Days_offered']]
# Out:
#                Days_offered
# offer_dropped
# No                58.425641
# Yes               84.018555

# %%
data.groupby('offer_dropped').median()[['age', 'percent_hike', 'total_rounds', 'satisfaction_index', 'no_companies_worked', 'total_experience', 'JHI', 'Days_offered']]
# Out:
#                 age  percent_hike  total_rounds  satisfaction_index  \
# offer_dropped
# No             36.0          22.0           6.0                59.0
# Yes            35.0          16.0           8.0                22.0
#
#                no_companies_worked  total_experience  JHI  Days_offered
# offer_dropped
# No                             5.0              12.0  2.2          64.0
# Yes                            5.0              10.0  2.0          91.0

# %%
data.groupby('offer_dropped').median()[['percent_hike']]
# Out:
#                percent_hike
# offer_dropped
# No                     22.0
# Yes                    16.0

# %%
data.groupby('offer_dropped').median()[['satisfaction_index']]
# Out:
#                satisfaction_index
# offer_dropped
# No                           59.0
# Yes                          22.0

# %%
data.groupby('offer_dropped').median()[['total_rounds']]
# Out:
#                total_rounds
# offer_dropped
# No                      6.0
# Yes                     8.0

# %%
data.groupby('offer_dropped').median()[['JHI']]
# Out:
#                JHI
# offer_dropped
# No             2.2
# Yes            2.0

# %%
data.groupby('offer_dropped').std()[['age', 'percent_hike', 'total_rounds', 'satisfaction_index', 'no_companies_worked', 'total_experience', 'JHI', 'Days_offered']]
# Out:
#                     age  percent_hike  total_rounds  satisfaction_index  \
# offer_dropped
# No             6.330156      9.080760      2.485084           20.452241
# Yes            5.916078      8.136069      2.565543            4.570875
#
#                no_companies_worked  total_experience       JHI  Days_offered
# offer_dropped
# No                        1.927897          6.238198  1.511931    130.355683
# Yes                       1.923805          5.793220  0.944403    123.604929

# %%
data.groupby('offer_dropped').std()[['percent_hike']]
# Out:
#                percent_hike
# offer_dropped
# No                 9.080760
# Yes                8.136069

# %%
data.groupby('offer_dropped').std()[['satisfaction_index']]
# Out:
#                satisfaction_index
# offer_dropped
# No                      20.452241
# Yes                      4.570875

# %%
data.groupby('offer_dropped').std()[['total_rounds']]
# Out:
#                total_rounds
# offer_dropped
# No                 2.485084
# Yes                2.565543

# %%
data.groupby('offer_dropped').std()[['JHI']]
# Out:
#                     JHI
# offer_dropped
# No             1.511931
# Yes            0.944403

# %% [markdown]
# **Index NO is bad, here mean and median does not shows properly the std deviation Showsproperly**

# %%
data.groupby('offer_dropped').var()[['percent_hike']]
# Out:
#                percent_hike
# offer_dropped
# No                82.460195
# Yes               66.195622

# %% [markdown]
# **Bivariate Boxplots**

# %%
sns.boxplot(y='age',data=data, x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
sns.boxplot(y='percent_hike',data=data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='percent_hike'>

# %%
sns.boxplot(y='satisfaction_index',data=data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='satisfaction_index'>

# %%
sns.boxplot(y='no_companies_worked',data=data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='no_companies_worked'>

# %%
sns.boxplot(y='total_experience',data=data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='total_experience'>

# %%
sns.boxplot(y='JHI',data=data,x='offer_dropped')
# Out:
# <AxesSubplot:xlabel='offer_dropped', ylabel='JHI'>

# %%
sns.boxplot(y='age',data=data,x='offer_dropped')
# Out:
# <AxesSubplot:xlabel='offer_dropped', ylabel='age'>

# %% [markdown]
# **Bivariate Scatter plots**

# %% [markdown]
# **Strip Plots**

# %%
sns.stripplot(x=data['career_growth'],y=data['JHI'])
# Out:
# <AxesSubplot:xlabel='career_growth', ylabel='JHI'>

# %% [markdown]
# **Swarm plots**

# %%
sns.swarmplot(x=data['career_growth'],y=data['JHI'])
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='career_growth', ylabel='JHI'>

# %% [markdown]
# **Violin Plots**

# %%
sns.set(rc={'figure.figsize':(5,7)})
sns.violinplot(x=data['career_growth'],y=data['JHI'],data=data)
# Out:
# <AxesSubplot:xlabel='career_growth', ylabel='JHI'>

# %% [markdown]
# # **Testing**

# %% [markdown]
# **Chisquare analysis**

# %% [markdown]
# **Test1**\
# **Test whether there is significant relationship between marital status and offer dropping**\
# Ho: No Relatipnship between variables
#
# H1: There is Relationship between variables

# %%
MO
# Out:
# offer_dropped    No  Yes
# marital_status
# divorced        103  102
# married         678  711
# single          190  210
# unknown           4    1

# %% [markdown]
# ### while if there any small values in the contigency table we need to convert it into any of the other, unknown can be changed to married or divorced

# %%
MO.plot(kind='bar', cmap ='cividis')
plt.title('Marital Status and Offer dropped\n', fontdict= {'fontsize':20, 'fontweight':5, 'color':'darkblue'})
# Out:
# Text(0.5, 1.0, 'Marital Status and Offer dropped\n')

# %%
import  scipy.stats as stats
from scipy.stats import chi2
alpha=0.05
values1=stats.chi2_contingency(MO)
values1
# Out:
# (2.389230347851195,
#  0.49564253863529995,
#  3,
#  array([[ 99.98749375, 105.01250625],
#         [677.47623812, 711.52376188],
#         [195.09754877, 204.90245123],
#         [  2.43871936,   2.56128064]]))

# %%
p_value1=values1[1]
p_value1
# Out:
# 0.49564253863529995

# %%
if p_value1 <= alpha:
   print("Reject H0")
else:
  print("Accept H0")
# Out:
# Accept H0

# %% [markdown]
# ### Since there is no relationship between Marital status and offer dropped we can delete marital status variables.
# so, if any varible is not related and there is no relationship between the offer dreopped we can remove those variables

# %% [markdown]
# **Test2**\
# **Test whether there is significant relationship between Sourcing Channel and offer dropping**\
# Ho: No Relatipnship between variables
#
# H1: There is Relationship between variables

# %%
SO
# Out:
# offer_dropped        No  Yes
# sourcing_channel
# Company Website     204  149
# Consultants         194  265
# Internal Referrals   85  196
# Job Portals         284  202
# Social Media        208  212

# %%
SO.plot(kind='bar', cmap ='cividis')
plt.title('Sourcing Channel and Offer dropped\n', fontdict= {'fontsize':20, 'fontweight':5, 'color':'darkblue'})
# Out:
# Text(0.5, 1.0, 'Sourcing Channel and Offer dropped\n')

# %%
alpha=0.05
values2=stats.chi2_contingency(SO)
values2
# Out:
# (76.11707162434504,
#  1.156388772239157e-15,
#  4,
#  array([[172.17358679, 180.82641321],
#         [223.87443722, 235.12556278],
#         [137.05602801, 143.94397199],
#         [237.04352176, 248.95647824],
#         [204.85242621, 215.14757379]]))

# %%
p_value2=values2[1]
p_value2
# Out:
# 1.156388772239157e-15

# %%
if p_value2 <= alpha:
   print("Reject H0")
else:
  print("Accept H0")
# Out:
# Reject H0

# %% [markdown]
# There is relationship between Sourcing channel and offerdropped, most of the offer dropping happend on consultants an then through social media
#
# least offer dropping happpens through company website
#
# most of the peoples through job portals doesn't dropped the offer.

# %% [markdown]
# **Test3**\
# **Test whether there is significant relationship between distance form home and offer dropping**\
# Ho: No Relatipnship between variables
#
# H1: There is Relationship between variables

# %%
DFHO=pd.crosstab(data['distance_from_home'],data['offer_dropped'])
DFHO
# Out:
# offer_dropped        No  Yes
# distance_from_home
# 15-20 kms           332  192
# <15 kms             321  373
# > 20 kms            322  459

# %%
DFHO.plot(kind='bar', cmap ='cividis')
plt.title('Distance From Home and Offer dropped\n', fontdict= {'fontsize':20, 'fontweight':5, 'color':'darkblue'})
# Out:
# Text(0.5, 1.0, 'Distance From Home and Offer dropped\n')

# %%
alpha=0.05
values3=stats.chi2_contingency(DFHO)
values3
# Out:
# (64.17030021781633,
#  1.163044566399746e-14,
#  2,
#  array([[255.57778889, 268.42221111],
#         [338.49424712, 355.50575288],
#         [380.92796398, 400.07203602]]))

# %%
p_value3=values3[1]
p_value3
# Out:
# 1.163044566399746e-14

# %%
if p_value3 <= alpha:
   print("Reject H0")
else:
  print("Accept H0")
# Out:
# Reject H0

# %% [markdown]
# There is a relationship between 2 variables, when distance increases the chance of dropping offer also increases
# even if the distance is higher also some people doesn't rejected the offer
